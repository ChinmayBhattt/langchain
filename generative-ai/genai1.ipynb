# %% [markdown]
# ## Langchain Version 1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.13

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Generative AI Application Using Agents

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
model
# Out:
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x1106d1fd0>, default_metadata=(), model_kwargs={})

# %%
# prompt = input()
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='The capital of India is **New Delhi**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d3d40-b73f-7ff3-822b-213b48880d45-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 9, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# The capital of India is **New Delhi**.

# %%
from langchain_openai import ChatOpenAI
model=ChatOpenAI(mode1="gpt-5")
response=model.invoke("Hello How are you")
response

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite"
)
llm.invoke("Hello How are you")
# Out:
# AIMessage(content="Hello! I'm doing well, thank you for asking. I'm an AI, so I don't experience feelings in the same way humans do, but I'm functioning optimally and ready to assist you.\n\nHow are **you** doing today? Is there anything I can help you with?", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d3d59-67eb-7ac0-8d0a-7403ffe65b44-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5, 'output_tokens': 63, 'total_tokens': 68, 'input_token_details': {'cache_read': 0}})

# %%
import os
os.environ["GEMINI_API_KEY"]=os.getenv("GEMINI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Write me an Essay about Artificial Intelligence")
print(response.content)
# Out:
# ## The Dawn of the Algorithmic Mind: Navigating the Promise and Peril of Artificial Intelligence
#
# Artificial Intelligence (AI), once confined to the realms of science fiction, has rapidly transitioned into a tangible force reshaping our world. From the mundane convenience of voice assistants to the complex calculations powering scientific discovery, AI's influence is pervasive and ever-expanding. This transformative technology, defined by its ability to perform tasks that typically require human intelligence – such as learning, problem-solving, and decision-making – stands at a critical juncture, promising unprecedented advancements while simultaneously raising profound ethical and societal questions. Understanding AI necessitates a balanced perspective, acknowledging its immense potential for good while grappling with its inherent challenges.
#
# At its core, AI's promise lies in its capacity to augment and amplify human capabilities. In fields like healthcare, AI algorithms can analyze vast datasets of medical images and patient histories with remarkable speed and accuracy, aiding in earlier disease detection and personalized treatment plans. In scientific research, AI is accelerating the pace of discovery, from designing new materials to unraveling the complexities of the universe. The automation of repetitive and dangerous tasks, facilitated by AI-powered robots and systems, can free up human workers for more creative and strategic endeavors, boosting productivity and improving safety. Furthermore, AI's ability to process and interpret information at scales unimaginable to humans can unlock solutions to some of our most pressing global challenges, from climate change modeling to optimizing resource allocation. The potential for AI to drive innovation, enhance efficiency, and improve the quality of human life is, without exaggeration, extraordinary.
#
# However, this transformative power is not without its inherent risks. The very intelligence that makes AI so powerful also necessitates careful consideration of its potential downsides. A primary concern revolves around the issue of bias. AI systems learn from the data they are trained on, and if that data reflects existing societal biases – whether racial, gender, or socioeconomic – the AI will inevitably perpetuate and even amplify these prejudices. This can lead to discriminatory outcomes in areas like hiring, loan applications, and even criminal justice. The "black box" nature of some advanced AI models, where the reasoning behind their decisions is opaque, further exacerbates this problem, making it difficult to identify and rectify biases.
#
# Another significant challenge lies in the realm of employment. As AI becomes more adept at performing a wider range of tasks, concerns about widespread job displacement are valid. While some argue that AI will create new jobs, the transition may be disruptive, requiring significant reskilling and upskilling of the workforce. The economic implications of such a shift, including the potential for increased income inequality, demand proactive policy interventions and a societal commitment to supporting those affected.
#
# Beyond practical concerns, AI also raises profound ethical and philosophical questions. The development of increasingly sophisticated AI, particularly in the area of artificial general intelligence (AGI) – AI that possesses human-level cognitive abilities across a wide range of tasks – prompts discussions about consciousness, sentience, and the very definition of life. As AI systems become more autonomous, questions of accountability and responsibility in the event of errors or harmful actions become paramount. Who is liable when an AI makes a mistake? The programmer, the deploying company, or the AI itself?
#
# Navigating this complex landscape requires a multi-faceted approach. Robust ethical frameworks and regulatory guidelines are crucial to ensure that AI is developed and deployed responsibly. Transparency in AI algorithms, where possible, and mechanisms for auditing and accountability are essential to mitigate bias and ensure fairness. Investment in education and training programs is vital to equip individuals with the skills needed to thrive in an AI-driven economy. Furthermore, ongoing public discourse and engagement are necessary to foster a shared understanding of AI's implications and to shape its development in alignment with societal values.
#
# In conclusion, Artificial Intelligence represents a profound technological leap, a testament to human ingenuity and our relentless pursuit of understanding and control. It holds the key to unlocking unprecedented progress and addressing some of humanity's most persistent problems. Yet, its immense power demands our deepest consideration and careful stewardship. By embracing AI's promise with a clear-eyed understanding of its perils, and by prioritizing ethical development, responsible deployment, and inclusive societal adaptation, we can strive to ensure that the dawn of the algorithmic mind ushers in an era of progress that benefits all of humanity, rather than exacerbating existing divides. The future of AI is not predetermined; it is being shaped by our choices today.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response=model.invoke("Capital of India?")
print(response.content)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# ## GROQ Model Integration
