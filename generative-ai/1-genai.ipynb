# %% [markdown]
# ## Langchain Version 1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.13

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Generative AI Application Using Agents

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")
model
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ChatGoogleGenerativeAI(profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), model='gemini-2.5-flash-lite', client=<google.genai.client.Client object at 0x11254a5d0>, default_metadata=(), model_kwargs={})

# %%
# prompt = input()
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='The capital of India is **New Delhi**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d3d40-b73f-7ff3-822b-213b48880d45-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 7, 'output_tokens': 9, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# The capital of India is **New Delhi**.

# %%
from langchain_openai import ChatOpenAI
model=ChatOpenAI(mode1="gpt-5")
response=model.invoke("Hello How are you")
response

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash-lite"
)
llm.invoke("Hello How are you")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# AIMessage(content='Hello! I am doing well, thank you for asking. I am a large language model, trained by Google. I am here and ready to help with any questions or tasks you may have. How are you doing today?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d3fe4-c280-7330-94ff-39c1e786f4f5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 5, 'output_tokens': 45, 'total_tokens': 50, 'input_token_details': {'cache_read': 0}})

# %%
import os
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Write me an Essay about Artificial Intelligence")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# ## The Dawn of the Algorithmic Mind: Navigating the Promise and Peril of Artificial Intelligence
#
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response=model.invoke("Capital of India?")
print(response.content)
# Out:
# The capital of India is **New Delhi**.

# %% [markdown]
# ## GROQ Model Integration

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model=init_chat_model("groq:llama-3.1-8b-instant")
response=model.invoke("Write me a joke on machine learning algorithms")
print(response.content)
# Out:
# Why did the neural network go to therapy?
#
# Because it was struggling to process its emotions and had a lot of "noise" in its life.

# %%
from langchain_groq import ChatGroq
import os

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

model = ChatGroq(model="groq:llama-3.1-8b-instant")
# response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# ## The Dawn of the Algorithmic Mind: Navigating the Promise and Peril of Artificial Intelligence
#
# Artificial Intelligence (AI), once a fantastical whisper in the realm of science fiction, has rapidly transformed into a palpable force shaping our present and charting the course of our future. From the mundane convenience of voice assistants to the complex machinations of self-driving cars and the groundbreaking discoveries in scientific research, AI is no longer a distant dream but a present reality. This burgeoning field, dedicated to creating machines that can perform tasks traditionally requiring human intelligence, presents a landscape of immense promise, capable of revolutionizing industries, solving complex global challenges, and augmenting human potential. However, this transformative power is inextricably linked to profound ethical, societal, and existential questions that demand our careful consideration and proactive engagement.
#
# ...

# %% [markdown]
# ## Streaming And Batch

# %% [markdown]
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses. Calling stream0 returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
from langchain_groq import ChatGroq

model = ChatGroq(model="llama-3.1-8b-instant")

response = model.invoke("Write me a 500 words paragraph on AI")
print(response.content)

# %%
# model.stream("Write me a 500 words paragraph on AI")

for chunk in model.stream("Write me a 1000 words paragraph on AI"):
    print(chunk.text, end="", flush=True) # flush - internal memory cache remove/flush

# %%
model.invoke("Why do parrots have colorful feathers?")

# %%
for chunck in model.stream("Why do parrots have colorful feathers?"):
    print(chunck.text, end="", flush=True)
# Out:
# Parrots have colorful feathers due to several reasons, primarily related to their evolution and behavior. Here are some possible explanations:
#
# 1. **Attracting mates**: Bright plumage is often used by male parrots to attract females and showcase their health, strength, and genetic quality. The more vibrant the colors, the more attractive the bird.
# 2. **Territorial display**: Parrots use their colorful feathers to defend their territory from other birds. By displaying their bright plumage, they can deter potential intruders and signal their ownership of the area.
# 3. **Communication**: Colorful feathers play a crucial role in parrot communication. They use their beaks, heads, and bodies to express emotions, intentions, and status. Bright colors can signal aggression, courtship, or other social cues.
# ...

# %% [markdown]
# ## Batch

# %% [markdown]
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
responses = model.batch(
    [
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
    ]
)

for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers due to a combination of factors, primarily related to their evolution, behavior, and ecology. The main reasons for their vibrant plumage are:\n\n1. **Mating and courtship**: Colorful feathers play a crucial role in attracting a mate. Bright colors signal the parrot's health, fertility, and genetic quality, making them more appealing to potential partners. This is especially important in species where pair bonds are long-term.\n2. **Territorial displays**: Parrots use their colorful feathers to establish dominance and defend their territory from other parrots. A parrot's vibrant plumage warns potential intruders to stay away, reducing the risk of conflict.\n3. **Communication**: Colors can convey information about a parrot's mood, social status, and intentions. For example, a parrot may display bright colors when feeling aggressive or during courtship displays.\n4. **Evolutionary pressures**: In the wild, parrots often live in dense forests or u
# ...

# %%
model.batch(
    [
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
    ],
    config={
        'max_concurrency': 5, # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers due to a combination of genetic and environmental factors. The main reasons for their vibrant plumage are:\n\n1. **Attracting a mate**: In the wild, colorful feathers play a crucial role in attracting potential mates. Bright colors are a visual signal that a parrot is healthy, strong, and capable of producing offspring with desirable traits.\n2. **Communication**: Colorful feathers help parrots communicate with each other. Different colors and patterns can convey information about a parrot's identity, social status, emotions, and intentions.\n3. **Camouflage and protection**: Some parrots have coloration that helps them blend in with their surroundings, making it easier to hide from predators or sneak up on prey.\n4. **Display and courtship**: During courtship, parrots will often display their brightest colors to attract a mate or to impress potential rivals.\n5. **Evolutionary adaptation**: The evolution of colorful feathers in parr
# ...
